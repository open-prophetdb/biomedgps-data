# %% [markdown]
# ## CustomDB
#
# Download from the prophet-studio.3steps.cn and upload to the customdb folder.
#
# You can connect to the database and fetch the related records by using the following sql query:
#
# ```sql
# SELECT relation_type,source_name,source_type,source_id,target_name,target_type,target_id,key_sentence,pmid FROM biomedgps_knowledge_curation WHERE curator = '1635231996@qq.com' AND source_id != 'Unknown:Unknown' AND target_id != 'Unknown:Unknown';
# ```

# %% [markdown]
# ### Reformat the curated knowledges as the BioMedGPS format

# %%
valid_entity_types = [
    "Compound",
    "Disease",
    "Gene",
    "Metabolite",
    "Pathway",
    "Anatomy",
    "Symptom",
    "PharmacologicClass",
    "BiologicalProcess",
    "CellularComponent",
    "MolecularFunction",
]

# %%
import pandas as pd

df = pd.read_csv("./customdb-v20240329.csv", sep=",")
# Filter all the rows with Unknown:Unknown values in the target_id or source_id columns
df = df[~df["target_id"].str.contains("Unknown:Unknown")]
df = df[~df["source_id"].str.contains("Unknown:Unknown")]
df["idx"] = df.index

# Join the source_type, target_type and relation_type columns
valid_relations = df[
    df["relation_type"].str.contains(".*:+[a-zA-Z]+:[a-zA-Z]+$", regex=True)
    & (
        df["source_type"].apply(lambda x: x in valid_entity_types)
        & df["target_type"].apply(lambda x: x in valid_entity_types)
    )
]
print(f"Valid relations: {valid_relations.shape[0]}")
invalid_relations = df[df["idx"].apply(lambda x: x not in valid_relations.index)]
print(f"Invalid relations: {invalid_relations.shape[0]}")

invalid_relations = invalid_relations.copy()
# Replace 'Protein' with 'Gene' in 'source_type' and 'target_type' columns
invalid_relations["source_type"] = invalid_relations["source_type"].replace(
    "Protein", "Gene"
)
invalid_relations["target_type"] = invalid_relations["target_type"].replace(
    "Protein", "Gene"
)

# Remove all rows which have a invalid source_type or target_type
invalid_relations = invalid_relations[
    (invalid_relations["source_type"].apply(lambda x: x in valid_entity_types))
    & (invalid_relations["target_type"].apply(lambda x: x in valid_entity_types))
].copy()

print(f"Invalid relations after fixing: {invalid_relations.shape[0]}")

invalid_relations["relation_type"] = invalid_relations.apply(
    lambda x: x["relation_type"] + "::" + x["source_type"] + ":" + x["target_type"],
    axis=1,
)
# Out:
# Valid relations: 989
# Invalid relations: 186
# Invalid relations after fixing: 186

# %%
print(invalid_relations["relation_type"].unique())
# Out:
# ['increased_by::BiologicalProcess:Disease'
#  'associated_with::Pathway:Disease'
#  'reduced_by::BiologicalProcess:Disease' 'reduced_by::Gene:Disease'
#  'associated_with::Compound:Disease' 'associated_with::Symptom:Disease'
#  'associated_with::Metabolite:Disease'
#  'associated_with::BiologicalProcess:Disease'
#  'biomarker::Compound:Disease' 'biomarker::Metabolite:Disease'
#  'inhibited_by::BiologicalProcess:Disease'
#  'associated_with::Anatomy:Disease' 'biomarker::Gene:Disease'
#  'biomarker::BiologicalProcess:Disease'
#  'biomarker::CellularComponent:Disease'
#  'biomarker::Disease:BiologicalProcess'
#  'associated_with::CellularComponent:Disease' 'treats::Compound:Disease'
#  'treats::Metabolite:Disease' 'associated_with::Disease:Compound'
#  'biomarker::Pathway:Disease' 'associated_with::Disease:BiologicalProcess'
#  'reduced_by::Metabolite:Disease' 'induced_by::BiologicalProcess:Disease'
#  'increased_by::Symptom:Disease' 'biomarker::Anatomy:Disease'
#  'reduced_by::Pathway:Disease' 'increased_by::Metabolite:Disease'
#  'downregulated_in::Metabolite:Disease' 'increased_by::Anatomy:Disease'
#  'reduced_by::Compound:Disease']

# %%
print(
    invalid_relations[
        invalid_relations["relation_type"] == "associated_with::Gene:Anatomy"
    ]
)
# Out:
#                       relation_type source_name source_type    source_id  \
# 1308  associated_with::Gene:Anatomy       IFN-γ        Gene  ENTREZ:3458
# 1329  associated_with::Gene:Anatomy         TNF        Gene  ENTREZ:7124
# 1330  associated_with::Gene:Anatomy       IL-1β        Gene  ENTREZ:3553
# 1333  associated_with::Gene:Anatomy       IL-1β        Gene  ENTREZ:3553
# 1334  associated_with::Gene:Anatomy         TNF        Gene  ENTREZ:7124
# 1335  associated_with::Gene:Anatomy       IFN-γ        Gene  ENTREZ:3458
#
#                 target_name target_type       target_id  \
# 1308  alveolar regeneration     Anatomy  UBERON:0002169
# 1329  alveolar regeneration     Anatomy  UBERON:0002169
# 1330     pulmonary function     Anatomy    MESH:D008168
# 1333  alveolar regeneration     Anatomy  UBERON:0002169
# 1334     pulmonary function     Anatomy    MESH:D008168
# 1335     pulmonary function     Anatomy    MESH:D008168
#
#                                            key_sentence      pmid   idx
# 1308  Notably, therapeutic neutralization of IFN-γ a...  37745354  1308
# 1329  Notably, therapeutic neutralization of IFN-γ a...  37745354  1329
# 1330  Notably, therapeutic neutralization of IFN-γ a...  37745354  1330
# 1333  Notably, therapeutic neutralization of IFN-γ a...  37745354  1333
# 1334  Notably, therapeutic neutralization of IFN-γ a...  37745354  1334
# 1335  Notably, therapeutic neutralization of IFN-γ a...  37745354  1335

# %% [markdown]
# ### Merge the formatted relations into one file

# %%
import pandas as pd

files = [
    "./formatted_customdb_v20240329.tsv",
    "./formatted_fuscc_bcdb_v20240923.tsv",
    "./formatted_malacards_mecfs.tsv",
    "./formatted_treatme_survey_compounds.tsv",
    "./formatted_treatme_survey_phenotypes.tsv",
]
merged = pd.concat([pd.read_csv(f, sep="\t") for f in files], ignore_index=True)
merged.to_csv("formatted_merged_all.tsv", sep="\t", index=False)

# %%
import os
import os.path as osp
import subprocess


def format_customdb(filename):
    def get_project_root():
        try:
            return osp.dirname(osp.dirname(os.getcwd()))
        except Exception as e:
            raise RuntimeError(f"Failed to determine project root: {e}")

    try:
        root_dir = get_project_root()
        print(f"Project root directory: {root_dir}")
    except RuntimeError as e:
        print(e)
        exit(1)

    database = "customdb"
    relations_path = osp.join(
        root_dir,
        "relations",
        "customdb",
        filename,
    )
    output_dir = osp.join(root_dir, "formatted_relations", "customdb")
    entities_path = osp.join(root_dir, "entities.tsv")
    log_file = osp.join(output_dir, "log.txt")

    command = [
        "graph-builder",
        "--database",
        database,
        "-d",
        relations_path,
        "-o",
        output_dir,
        "-f",
        entities_path,
        "-n",
        "20",
        "--download",
        "--skip",
        "-l",
        log_file,
        "--debug",
    ]

    print("Executing command:", " ".join(command))

    try:
        subprocess.run(command, check=True)
    except FileNotFoundError:
        print(
            "Error: 'graph-builder' command not found. Make sure it is installed and available in the PATH."
        )
        exit(1)
    except subprocess.CalledProcessError as e:
        print(f"Error: Command execution failed with return code {e.returncode}")
        print(f"Output: {e.output}")
        exit(1)
    except Exception as e:
        print(f"Unexpected error: {e}")
        exit(1)

# %%
format_customdb("formatted_merged_all.tsv")
# Out:
# Project root directory: /Users/jy006/Documents/Code/BioMedGPS/biomedgps-data/graph_data
# Executing command: graph-builder --database customdb -d /Users/jy006/Documents/Code/BioMedGPS/biomedgps-data/graph_data/relations/customdb/formatted_merged_all.tsv -o /Users/jy006/Documents/Code/BioMedGPS/biomedgps-data/graph_data/formatted_relations/customdb -f /Users/jy006/Documents/Code/BioMedGPS/biomedgps-data/graph_data/entities.tsv -n 20 --download --skip -l /Users/jy006/Documents/Code/BioMedGPS/biomedgps-data/graph_data/formatted_relations/customdb/log.txt --debug
# 2024-11-12 12:46:59 - cli:159 - INFO - Run jobs with (output_dir: /Users/jy006/Documents/Code/BioMedGPS/biomedgps-data/graph_data/formatted_relations/customdb, db file/directory: /Users/jy006/Documents/Code/BioMedGPS/biomedgps-data/graph_data/relations/customdb/formatted_merged_all.tsv, databases: ('customdb',), download: True, skip: True)
# 2024-11-12 12:47:01 - base_parser:116 - WARNING - The relation_type should be in the format of '[database_name]::[relation_type]::[head_entity_id]:[tail_entity_id]', but got the following relation types: ['PrimeKG::parent-child:Disease:Disease', 'PrimeKG::contraindication:Compound:Disease', 'HSDN::has_symptom:Disease:Symptom', 'PrimeKG::contraindication:Disease:Compound', 'PrimeKG::associated_with:Gene:Disease'].
# 2024-11-12 12:47:01 - customdb_parser:78 - WARNING - The relation_type column contains invalid relation types. ['PrimeKG::parent-child:Disease:Disease', 'PrimeKG::contraindication:Compound:Disease', 'HSDN::has_symptom:Disease:Symptom', 'PrimeKG::contraindication:Disease:Compound', 'PrimeKG::associated_with:Gene:Disease']
# 2024-11-12 12:47:01 - customdb_parser:95 - INFO - Get 1152 relations
# 2024-11-12 12:47:01 - base_parser:475 - INFO - Found 1152 relations.
# 2024-11-12 12:47:01 - base_parser:783 - INFO - Start to get entity id map.
# 2024-11-12 12:47:08 - base_parser:817 - INFO - The number of deduped entity type ids: 749
# 2024-11-12 12:50:28 - base_parser:827 - INFO - The number of entity ids: 749
# 2024-11-12 12:50:28 - base_parser:477 - INFO - Found 749 entity ids in entity id map.
# 2024-11-12 12:50:28 - base_parser:491 - INFO - The number of relations before dropna: 1152
# 2024-11-12 12:50:28 - base_parser:493 - INFO - The number of relations after dropna: 1152
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 0.00%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 0.18%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 0.37%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 0.55%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 0.74%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 0.92%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 1.11%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 1.29%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 1.48%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 1.66%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 1.85%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 2.03%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 2.22%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 2.40%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 2.59%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 2.77%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 2.96%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 3.14%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 3.33%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 3.51%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 3.70%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 3.88%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 4.07%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 4.25%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 4.44%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 4.62%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 4.81%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 4.99%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 5.18%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 5.36%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 5.55%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 5.73%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 5.91%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 6.10%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 6.28%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 6.47%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 6.65%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 6.84%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 7.02%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 7.21%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 7.39%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 7.58%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 7.76%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 7.95%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 8.13%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 8.32%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 8.50%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 8.69%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 8.87%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 9.06%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 9.24%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 9.43%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 9.61%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 9.80%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 9.98%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 10.17%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 10.35%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 10.54%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 10.72%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 10.91%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 11.09%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 11.28%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 11.46%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 11.65%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 11.83%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 12.01%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 12.20%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 12.38%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 12.57%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 12.75%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 12.94%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 13.12%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 13.31%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 13.49%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 13.68%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 13.86%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 14.05%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 14.23%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 14.42%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 14.60%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 14.79%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 14.97%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 15.16%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 15.34%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 15.53%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 15.71%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 15.90%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 16.08%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 16.27%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 16.45%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 16.64%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 16.82%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 17.01%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 17.19%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 17.38%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 17.56%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 17.74%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 17.93%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 18.11%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 18.30%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 18.48%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 18.67%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 18.85%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 19.04%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 19.22%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 19.41%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 19.59%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 19.78%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 19.96%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 20.15%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 20.33%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 20.52%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 20.70%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 20.89%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 21.07%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 21.26%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 21.44%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 21.63%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 21.81%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 22.00%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 22.18%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 22.37%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 22.55%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 22.74%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 22.92%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 23.11%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 23.29%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 23.48%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 23.66%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 23.84%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 24.03%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 24.21%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 24.40%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 24.58%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 24.77%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 24.95%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 25.14%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 25.32%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 25.51%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 25.69%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 25.88%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 26.06%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 26.25%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 26.43%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 26.62%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 26.80%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 26.99%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 27.17%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 27.36%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 27.54%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 27.73%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 27.91%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 28.10%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 28.28%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 28.47%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 28.65%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 28.84%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 29.02%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 29.21%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 29.39%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 29.57%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 29.76%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 29.94%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 30.13%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 30.31%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 30.50%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 30.68%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 30.87%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 31.05%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 31.24%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 31.42%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 31.61%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 31.79%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 31.98%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 32.16%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 32.35%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 32.53%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 32.72%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 32.90%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 33.09%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 33.27%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 33.46%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 33.64%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 33.83%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 34.01%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 34.20%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 34.38%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 34.57%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 34.75%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 34.94%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 35.12%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 35.30%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 35.49%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 35.67%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 35.86%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 36.04%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 36.23%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 36.41%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 36.60%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 36.78%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 36.97%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 37.15%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 37.34%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 37.52%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 37.71%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 37.89%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 38.08%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 38.26%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 38.45%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 38.63%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 38.82%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 39.00%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 39.19%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 39.37%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 39.56%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 39.74%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 39.93%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 40.11%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 40.30%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 40.48%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 40.67%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 40.85%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 41.04%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 41.22%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 41.40%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 41.59%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 41.77%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 41.96%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 42.14%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 42.33%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 42.51%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 42.70%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 42.88%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 43.07%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 43.25%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 43.44%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 43.62%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 43.81%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 43.99%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 44.18%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 44.36%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 44.55%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 44.73%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 44.92%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 45.10%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 45.29%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 45.47%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 45.66%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 45.84%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 46.03%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 46.21%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 46.40%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 46.58%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 46.77%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 46.95%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 47.13%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 47.32%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 47.50%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 47.69%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 47.87%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 48.06%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 48.24%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 48.43%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 48.61%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 48.80%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 48.98%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 49.17%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 49.35%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 49.54%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 49.72%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 49.91%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 50.09%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 50.28%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 50.46%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 50.65%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 50.83%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 51.02%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 51.20%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 51.39%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 51.57%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 51.76%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 51.94%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 52.13%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 52.31%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 52.50%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 52.68%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 52.87%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 53.05%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 53.23%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 53.42%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 53.60%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 53.79%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 53.97%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 54.16%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 54.34%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 54.53%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 54.71%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 54.90%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 55.08%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 55.27%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 55.45%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 55.64%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 55.82%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 56.01%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 56.19%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 56.38%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 56.56%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 56.75%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 56.93%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 57.12%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 57.30%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 57.49%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 57.67%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 57.86%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 58.04%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 58.23%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 58.41%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 58.60%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 58.78%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 58.96%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 59.15%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 59.33%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 59.52%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 59.70%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 59.89%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 60.07%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 60.26%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 60.44%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 60.63%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 60.81%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 61.00%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 61.18%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 61.37%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 61.55%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 61.74%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 61.92%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 62.11%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 62.29%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 62.48%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 62.66%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 62.85%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 63.03%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 63.22%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 63.40%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 63.59%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 63.77%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 63.96%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 64.14%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 64.33%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 64.51%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 64.70%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 64.88%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 65.06%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 65.25%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 65.43%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 65.62%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 65.80%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 65.99%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 66.17%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 66.36%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 66.54%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 66.73%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 66.91%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 67.10%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 67.28%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 67.47%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 67.65%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 67.84%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 68.02%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 68.21%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 68.39%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 68.58%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 68.76%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 68.95%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 69.13%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 69.32%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 69.50%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 69.69%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 69.87%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 70.06%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 70.24%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 70.43%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 70.61%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 70.79%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 70.98%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 71.16%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 71.35%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 71.53%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 71.72%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 71.90%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 72.09%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 72.27%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 72.46%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 72.64%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 72.83%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 73.01%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 73.20%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 73.38%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 73.57%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 73.75%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 73.94%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 74.12%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 74.31%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 74.49%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 74.68%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 74.86%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 75.05%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 75.23%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 75.42%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 75.60%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 75.79%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 75.97%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 76.16%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 76.34%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 76.52%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 76.71%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 76.89%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 77.08%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 77.26%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 77.45%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 77.63%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 77.82%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 78.00%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 78.19%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 78.37%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 78.56%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 78.74%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 78.93%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 79.11%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 79.30%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 79.48%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 79.67%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 79.85%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 80.04%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 80.22%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 80.41%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 80.59%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 80.78%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 80.96%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 81.15%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 81.33%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 81.52%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 81.70%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 81.89%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 82.07%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 82.26%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 82.44%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 82.62%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 82.81%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 82.99%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 83.18%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 83.36%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 83.55%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 83.73%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 83.92%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 84.10%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 84.29%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 84.47%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 84.66%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 84.84%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 85.03%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 85.21%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 85.40%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 85.58%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 85.77%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 85.95%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 86.14%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 86.32%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 86.51%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 86.69%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 86.88%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 87.06%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 87.25%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 87.43%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 87.62%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 87.80%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 87.99%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 88.17%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 88.35%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 88.54%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 88.72%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 88.91%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 89.09%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 89.28%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 89.46%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 89.65%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 89.83%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 90.02%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 90.20%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 90.39%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 90.57%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 90.76%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 90.94%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 91.13%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 91.31%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 91.50%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 91.68%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 91.87%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 92.05%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 92.24%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 92.42%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 92.61%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 92.79%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 92.98%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 93.16%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 93.35%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 93.53%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 93.72%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 93.90%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 94.09%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 94.27%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 94.45%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 94.64%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 94.82%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 95.01%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 95.19%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 95.38%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 95.56%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 95.75%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 95.93%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 96.12%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 96.30%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 96.49%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 96.67%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 96.86%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 97.04%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 97.23%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 97.41%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 97.60%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 97.78%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 97.97%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 98.15%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 98.34%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 98.52%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 98.71%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 98.89%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 99.08%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 99.26%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 99.45%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 99.63%
# 2024-11-12 12:50:28 - base_parser:501 - INFO - Processing 99.82%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 0.00%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 0.37%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 0.75%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 1.12%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 1.50%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 1.87%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 2.25%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 2.62%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 3.00%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 3.37%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 3.75%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 4.12%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 4.49%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 4.87%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 5.24%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 5.62%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 5.99%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 6.37%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 6.74%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 7.12%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 7.49%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 7.87%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 8.24%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 8.61%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 8.99%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 9.36%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 9.74%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 10.11%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 10.49%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 10.86%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 11.24%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 11.61%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 11.99%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 12.36%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 12.73%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 13.11%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 13.48%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 13.86%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 14.23%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 14.61%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 14.98%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 15.36%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 15.73%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 16.10%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 16.48%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 16.85%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 17.23%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 17.60%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 17.98%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 18.35%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 18.73%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 19.10%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 19.48%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 19.85%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 20.22%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 20.60%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 20.97%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 21.35%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 21.72%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 22.10%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 22.47%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 22.85%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 23.22%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 23.60%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 23.97%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 24.34%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 24.72%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 25.09%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 25.47%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 25.84%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 26.22%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 26.59%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 26.97%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 27.34%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 27.72%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 28.09%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 28.46%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 28.84%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 29.21%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 29.59%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 29.96%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 30.34%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 30.71%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 31.09%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 31.46%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 31.84%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 32.21%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 32.58%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 32.96%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 33.33%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 33.71%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 34.08%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 34.46%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 34.83%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 35.21%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 35.58%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 35.96%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 36.33%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 36.70%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 37.08%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 37.45%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 37.83%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 38.20%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 38.58%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 38.95%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 39.33%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 39.70%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 40.07%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 40.45%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 40.82%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 41.20%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 41.57%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 41.95%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 42.32%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 42.70%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 43.07%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 43.45%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 43.82%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 44.19%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 44.57%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 44.94%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 45.32%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 45.69%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 46.07%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 46.44%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 46.82%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 47.19%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 47.57%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 47.94%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 48.31%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 48.69%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 49.06%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 49.44%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 49.81%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 50.19%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 50.56%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 50.94%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 51.31%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 51.69%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 52.06%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 52.43%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 52.81%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 53.18%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 53.56%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 53.93%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 54.31%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 54.68%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 55.06%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 55.43%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 55.81%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 56.18%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 56.55%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 56.93%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 57.30%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 57.68%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 58.05%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 58.43%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 58.80%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 59.18%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 59.55%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 59.93%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 60.30%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 60.67%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 61.05%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 61.42%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 61.80%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 62.17%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 62.55%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 62.92%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 63.30%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 63.67%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 64.04%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 64.42%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 64.79%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 65.17%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 65.54%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 65.92%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 66.29%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 66.67%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 67.04%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 67.42%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 67.79%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 68.16%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 68.54%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 68.91%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 69.29%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 69.66%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 70.04%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 70.41%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 70.79%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 71.16%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 71.54%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 71.91%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 72.28%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 72.66%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 73.03%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 73.41%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 73.78%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 74.16%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 74.53%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 74.91%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 75.28%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 75.66%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 76.03%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 76.40%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 76.78%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 77.15%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 77.53%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 77.90%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 78.28%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 78.65%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 79.03%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 79.40%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 79.78%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 80.15%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 80.52%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 80.90%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 81.27%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 81.65%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 82.02%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 82.40%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 82.77%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 83.15%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 83.52%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 83.90%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 84.27%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 84.64%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 85.02%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 85.39%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 85.77%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 86.14%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 86.52%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 86.89%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 87.27%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 87.64%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 88.01%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 88.39%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 88.76%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 89.14%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 89.51%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 89.89%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 90.26%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 90.64%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 91.01%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 91.39%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 91.76%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 92.13%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 92.51%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 92.88%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 93.26%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 93.63%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 94.01%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 94.38%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 94.76%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 95.13%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 95.51%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 95.88%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 96.25%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 96.63%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 97.00%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 97.38%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 97.75%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 98.13%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 98.50%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 98.88%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 99.25%
# 2024-11-12 12:50:28 - base_parser:512 - INFO - Processing 99.63%
# 2024-11-12 12:50:28 - base_parser:520 - INFO - The number of relations: 1152
# 2024-11-12 12:50:28 - base_parser:539 - INFO - Remove the combined_key column.
# 2024-11-12 12:50:28 - base_parser:564 - INFO - The relation type dictionary is not provided, skip to replace the relation type with the formatted relation type.
# 2024-11-12 12:50:28 - base_parser:620 - INFO - Check and swap source_id and target_id if needed.
# 2024-11-12 12:50:28 - base_parser:624 - INFO - The number of relations before filter_na: 1152
# 2024-11-12 12:50:28 - base_parser:630 - INFO - Found 77 invalid relations, all invalid relations are saved in /Users/jy006/Documents/Code/BioMedGPS/biomedgps-data/graph_data/formatted_relations/customdb/unformatted_customdb.tsv
# 2024-11-12 12:50:28 - base_parser:684 - INFO - Found 52 unformatted entities and they are saved in /Users/jy006/Documents/Code/BioMedGPS/biomedgps-data/graph_data/formatted_relations/customdb/unformatted_customdb_entities.tsv
# 2024-11-12 12:50:28 - base_parser:716 - INFO - The number of relations before drop_duplicates: 1075
# 2024-11-12 12:50:28 - base_parser:747 - INFO - Found 220 duplicated relations and they are saved in /Users/jy006/Documents/Code/BioMedGPS/biomedgps-data/graph_data/formatted_relations/customdb/duplicated_customdb.tsv
# 2024-11-12 12:50:28 - base_parser:758 - INFO - Finally, save 944 relations in /Users/jy006/Documents/Code/BioMedGPS/biomedgps-data/graph_data/formatted_relations/customdb/formatted_customdb.tsv
