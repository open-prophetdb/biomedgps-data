# %% [markdown]
# ### Find matched ids for drugs and side effects in ChSe-Decagon_monopharmacy.csv.gz
#
# Our knowledge graph is based on the DrugBank database. Before we use the drug-sideeffect file to annotate our predicted results, we need to find the drug bank ids for all drugs and the MESH/SYMP ids for all side effects in the file.

# %% [markdown]
# ### Dependencies

# %%
import pandas as pd
import requests
import json


def convert_pubchem_to_drugbank(pubchem_ids):
    # mychem.info API URL
    url = "https://mychem.info/v1/query"

    # Dictionary to hold DrugBank to MeSH ID mappings
    mapping = {}

    for i in range(0, len(pubchem_ids), 100):
        # Prepare the query
        q = ",".join(pubchem_ids[i : i + 100])
        params = {
            "q": q,
            "fields": "drugbank.id,drugcentral.xrefs.drugbank_id,pharmgkb.xrefs.drugbank,unichem.drugbank",
            "scopes": "pubchem.cid",
        }

        # Send the request
        response = requests.post(url, params=params)

        # Check if the response is valid
        print(response.status_code, response.text)
        results = response.json()
        for result in results:
            if result.get("drugbank"):
                mapping[result["query"]] = result["drugbank"]["id"]
            else:
                mapping[result["query"]] = None

    return mapping


def convert_id_to_umls(id, id_type, api_key):
    """
    Convert a ID to UMLS ID using BioPortal's REST API.

    :param id: The ID to convert.
    :param id_type: The type of ID to convert. Must be one of MESH, SNOMEDCT, SYMP, MEDDRA.
    :param api_key: Your BioPortal API key.
    :return: The corresponding UMLS ID, if found.
    """
    base_url = "http://data.bioontology.org"
    headers = {"Authorization": f"apikey token={api_key}"}

    # More details on the API here: https://data.bioontology.org/documentation#Class
    # You can get the related UMLS ids for SYMP from the downloaded file here: https://bioportal.bioontology.org/ontologies/SYMP?p=summary
    if id_type not in ["MESH", "SNOMEDCT", "MEDDRA"]:
        print(
            f"Error: {id_type} is not a valid ID type, must be one of MESH, SNOMEDCT, MEDDRA"
        )
        return None

    if id_type in ["MESH", "SNOMEDCT", "MEDDRA"]:
        path = f"http%3A%2F%2Fpurl.bioontology.org%2Fontology%2F{id_type}%2F{id}"

    url = f"{base_url}/ontologies/{id_type}/classes/{path}"
    print("The URL is: ", url)

    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        data = response.json()
        print(json.dumps(data, indent=2))
        mappings = data.get("cui", [])
        if len(mappings) > 0:
            return mappings[0]
        else:
            print(f"Error: No mappings found for {id}")
            return None
    else:
        print(f"Error: {response.status_code}")
        return None

# %% [markdown]
# ### Convert the pubchem ids to drugbank ids

# %% [markdown]
# #### Input

# %%
import pandas as pd

data = pd.read_csv(
    "./ChSe-Decagon_monopharmacy.csv.gz",
    compression="gzip",
)
output_file = "./ChSe-Decagon_monopharmacy_drugbank.csv"

# %% [markdown]
# #### Output

# %%
data = data.rename(
    columns={
        "# STITCH": "pubchem_id",
        "Individual Side Effect": "ulms_id",
        "Side Effect Name": "side_effect_name",
    }
)

# %%
pubchem_ids = data["pubchem_id"].unique().tolist()
formatted_pubchem_ids = [x.replace("CID", "").strip("0") for x in pubchem_ids]
id_map = dict(zip(pubchem_ids, formatted_pubchem_ids))
mapping = convert_pubchem_to_drugbank(formatted_pubchem_ids)

drugbank_ids = []
for pubchem_id in data["pubchem_id"]:
    drugbank_id = mapping.get(id_map.get(pubchem_id))
    drugbank_ids.append(drugbank_id)
data["drugbank_id"] = drugbank_ids
# Out:
# 200 [{"query":"3062316","_id":"ZBNZXTGUTAYRHI-UHFFFAOYSA-N","_score":17.083454,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB01254"}},{"query":"3117","_id":"AUZONCFQVSMFAP-UHFFFAOYSA-N","_score":17.083454,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00822"}},{"query":"3114","_id":"UVTNFZQICZKOEM-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00280"}},{"query":"373","notfound":true},{"query":"3736","_id":"DGAIEPBNLOQYER-UHFFFAOYSA-N","_score":17.083454,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB09156"}},{"query":"3734","_id":"XQZXYNRDCRIARQ-UHFFFAOYSA-N","_score":17.083544},{"query":"2646","_id":"WDLWHQDACQUCJR-UHFFFAOYSA-N","_score":17.08357},{"query":"28112","_id":"OCZDCIYGECBNKL-UHFFFAOYSA-N","_score":17.083454},{"query":"4183806","_id":"OJLOPKGSLYJEMD-UHFFFAOYSA-N","_score":17.083454},{"query":"2462","_id":"VOVIALXJUBGFJZ-UHFFFAOYSA-N","_score":17.083454},{"query":"5381","_id":"OGQICQVSFDPSEI-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00799"}},{"query":"125889","_id":"AYXYPKUFHZROOJ-SSDOTTSWSA-N","_score":17.08357},{"query":"5245","_id":"IIDJRNMFWXDHID-UHFFFAOYSA-N","_score":17.083454,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00884"}},{"query":"4034","_id":"OCJYIGYOJCODJL-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00737"}},{"query":"3937","_id":"RLAWWYSOJDYHDC-UHFFFAOYSA-N","_score":17.083454},{"query":"536207","_id":"VTBQKZAUDZZVBC-UHFFFAOYSA-N","_score":17.083454},{"query":"3121","_id":"NIJJYAXOARWZEE-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00313"}},{"query":"3382","_id":"WJOHZNCJWYWUJD-UHFFFAOYSA-N","_score":17.08357},{"query":"3381","_id":"FEBLZLNTKCEFIT-UHFFFAOYSA-N","_score":17.083544},{"query":"3386","_id":"RTHCYVBBDHJXIQ-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00472"}},{"query":"3384","_id":"FAOZLTXFLGPHNG-UHFFFAOYSA-N","_score":17.083454},{"query":"3385","_id":"GHASVSINZRGABV-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00544"}},{"query":"2656","_id":"VAAUVRVFOQPIGI-UHFFFAOYSA-L","_score":17.083454},{"query":"265","_id":"CRFNGMNYKDXRTN-UHFFFAOYSA-N","_score":17.083454},{"query":"3706","_id":"CBVCZFGXHXORBI-UHFFFAOYSA-N","_score":17.08357},{"query":"3702","_id":"NDDAHWYSQHTHNT-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00808"}},{"query":"5978","_id":"OGWKCGZFUXNPDA-XQKSVPLYSA-N","_score":17.08357},{"query":"2471","_id":"MAEIEVLCKWDQJH-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00887"}},{"query":"2477","_id":"QWCRAEMEVRGPNT-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00490"}},{"query":"2476","_id":"RMRJXGBAOAMLHD-UHFFFAOYSA-N","_score":17.083544},{"query":"2474","_id":"LEBVLXFERQHONN-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00297"}},{"query":"2478","_id":"COVZYZSDYWQREU-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB01008"}},{"query":"5394","_id":"BPEGJWRSRHCHSN-UHFFFAOYSA-N","_score":17.083454,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00853"}},{"query":"5391","_id":"SEQDDYPDSLOBDC-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00231"}},{"query":"41693","_id":"GGCSSNBKKAUURC-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00708"}},{"query":"57537","_id":"KFQYTPMOWPVWEJ-UHFFFAOYSA-N","_score":17.083454},{"query":"4739","_id":"FPVKHBSQESCIEP-UHFFFAOYSA-N","_score":17.083544},{"query":"4736","_id":"VOKSWYLNZZRQPF-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00652"}},{"query":"473","_id":"SXFSQZDSUWACKX-UHFFFAOYSA-N","_score":17.08357,"drugbank":{" ...
# 200 [{"query":"24486","_id":"QHFQAJHNDKBRBO-UHFFFAOYSA-L","_score":17.08357},{"query":"5212","notfound":true},{"query":"521","_id":"QHHKKMYHDBRONY-UHFFFAOYSA-N","_score":17.083454},{"query":"5215","_id":"SEEPANYCNGTZFQ-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00359"}},{"query":"4075","_id":"KBOPZPXVLCULAV-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00244"}},{"query":"5593","_id":"BGDKAVGWHJFAGW-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00809"}},{"query":"1134","_id":"IQFYYKKMVGJFEH-UHFFFAOYSA-N","_score":17.08357},{"query":"191","_id":"OIRDTQYFTABQOQ-UHFFFAOYSA-N","_score":17.08357},{"query":"3869","_id":"SGUAFYQXFOLMHL-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00598"}},{"query":"3152","_id":"ADEBPBSSDYVVLD-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00843"}},{"query":"68844","_id":"HCRKCZRJWPKOAR-JTQLQIEISA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB01194"}},{"query":"772","_id":"HTTJABKRGRZYRN-UHFFFAOYSA-N","_score":17.083544},{"query":"5206","_id":"DFEYYRMXOJXZRJ-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB01236"}},{"query":"123631","_id":"XGALLCVXEZPNRQ-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00317"}},{"query":"3075","_id":"HSUGRBWQSSZJOP-UHFFFAOYSA-O","_score":17.083544},{"query":"3696","_id":"BCGWQEUPMDMJNV-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00458"}},{"query":"369","notfound":true},{"query":"261","_id":"ZTQSAGDEMFDKMZ-UHFFFAOYSA-N","_score":17.083544},{"query":"2617","_id":"MLYYVTUWGNIJIB-UHFFFAOYSA-M","_score":17.08357},{"query":"6874","_id":"PMGCQNGBLMMXEW-UHFFFAOYSA-N","_score":17.083544},{"query":"77992","_id":"XPSQPHWEGNHMSK-SECBINFHSA-N","_score":17.083454,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00998"}},{"query":"77993","_id":"PWVXXGRKLHYWKM-LJQANCHMSA-N","_score":17.083454,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00216"}},{"query":"77999","_id":"YASAKCUCGLMORW-UHFFFAOYSA-N","_score":17.083454,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00412"}},{"query":"3488","_id":"ZNNLBTZKUZBEKO-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB01016"}},{"query":"5029","_id":"YREYEVIYCVEVJK-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB01129"}},{"query":"4513","_id":"SGXXNSQHWDMGGP-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00585"}},{"query":"451","notfound":true},{"query":"4889","_id":"TUZYXOIXSAXUGO-UHFFFAOYSA-N","_score":17.083454},{"query":"4885","_id":"FASDKYOPVNHBLU-UHFFFAOYSA-N","_score":17.083544},{"query":"5203","_id":"VGKDLMBJGBXTGI-UHFFFAOYSA-N","_score":17.08357},{"query":"72467","_id":"OYVAGSVQBOHSSS-VGWQMFASSA-O","_score":17.08357},{"query":"213039","_id":"CJBJHOAVZSMMDJ-HEXNFIEUSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB01264"}},{"query":"3066","_id":"LUZRJRNZXALNLM-UHFFFAOYSA-N","_score":17.08357},{"query":"2622","_id":"HVFLCNVBZFFHBT-UHFFFAOYSA-N","_score":17.083454},{"query":"3203","_id":"XPOQHMRABVBWPR-UHFFFAOYSA-N","_score":17.083544},{"query":"5454","_id":"GFBKORZTTCHDGY-UHFFFAOYSA-N","_score":17.083454},{"query":"2487","_id":"IFKLAQQSCNILHL-UHFFFAOYSA-N","_score":17.08357},{"query":"9386","_id":"UWEYRJFJVCLAGH-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB16292"}},{"query":"74989","_id":"BSJMWHQBCZFXBR-UHFFFAOYSA-N","_score":17.08357},{"query":"17687","_id":"UFVDXEXHBVQKGB-UHFFFAOYSA-L","_score":17.083454},{"query":"4506","_id":"KJONHKAYOJNZEC-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB01595"}},{"query":"2554","_id ...
# 200 [{"query":"6918453","_id":"AUJRCFUBUPVWSZ-XTZHGVARSA-M","_score":17.083454,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00995"}},{"query":"163742","_id":"KANJSNBRCNMZMV-HFBWGYJZSA-N","_score":17.083544},{"query":"54841","_id":"VHGCDTVCOLNTBX-QGZVFWFLSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00289"}},{"query":"3032","_id":"DCOPUUMXTXDBNB-UHFFFAOYSA-M","_score":17.083544},{"query":"4828","_id":"JZQKKSLKJUAGIC-UHFFFAOYSA-N","_score":17.083454,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00960"}},{"query":"3784","_id":"HMJIYCCIJYRONP-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00270"}},{"query":"378","_id":"XZKIHKMTEMTJQX-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB04214"}},{"query":"2786","_id":"KDLRVYVGXIQJDK-UHFFFAOYSA-N","_score":17.083544},{"query":"3986","_id":"ARKDJZHBBZECNE-UHFFFAOYSA-N","_score":17.083544},{"query":"5064","_id":"IWUCXVSUMQZMFG-UHFFFAOYSA-N","_score":17.08357},{"query":"5538","_id":"SHGAZHPCJJPHSC-UHFFFAOYSA-N","_score":17.083454},{"query":"444","_id":"SNPPWIUOZRMYNY-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB01156"}},{"query":"2215","_id":"VMWNQDUVQKEIOC-UHFFFAOYSA-N","_score":17.083544},{"query":"5533","_id":"PHLBKPHSAVXXEF-UHFFFAOYSA-N","_score":17.083454,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00656"}},{"query":"553","_id":"HNOAJOYERZTSNK-UHFFFAOYSA-N","_score":17.083544},{"query":"4112","_id":"FBOZXECLQNJBKD-UHFFFAOYSA-N","_score":17.08357},{"query":"3081884","_id":"FHEAIOHRHQGZPC-KIWGSFCNSA-N","_score":17.08357},{"query":"1546","_id":"PTOAARAWEBMLNO-UHFFFAOYSA-N","_score":17.08357},{"query":"54786","_id":"PAJMKGZZBBTTOY-YRIDSSQKSA-N","_score":17.08357},{"query":"942","_id":"SNICXCGAKADSCV-UHFFFAOYSA-N","_score":17.083544},{"query":"104741","_id":"VWUXBMIQPBEWFH-WCCTWKNTSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00947"}},{"query":"5478","_id":"BLJRIMJGRPQVNF-UHFFFAOYSA-N","_score":17.083454},{"query":"3793","_id":"VHVPQPYKVGDNFY-UHFFFAOYSA-N","_score":17.08357},{"query":"2311","_id":"XPCFTKFZXHTYIP-UHFFFAOYSA-N","_score":17.08357},{"query":"2771","_id":"WSEQXVZVJXJVFP-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00215"}},{"query":"152945","_id":"JWJOTENAMICLJG-VYZSUTEISA-N","_score":17.08357},{"query":"2512","_id":"KORNTPPJEAJQIU-UHFFFAOYSA-N","_score":17.08357},{"query":"2519","_id":"RYYVLZVUVIJVGH-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00201"}},{"query":"5505","_id":"JLRGJRBPOGGCBT-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB01124"}},{"query":"27991","_id":"NFLWUMRGJYTJIN-UHFFFAOYSA-N","_score":17.083544},{"query":"4509","_id":"NXFQHRVNIOXGAQ-UHFFFAOYSA-N","_score":17.083454},{"query":"4107","_id":"GNXFOGHNGIVQEH-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00423"}},{"query":"206","_id":"WQZGKKKJIJFFOK-UHFFFAOYSA-N","_score":17.08357},{"query":"937","_id":"PVNIIMVLHYAWGP-UHFFFAOYSA-M","_score":17.083544},{"query":"3016","_id":"AAOVKJBEBIDNHE-UHFFFAOYSA-N","_score":17.083454,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00829"}},{"query":"5311082","_id":"ITPPZKQWHHMJQQ-LROMGURASA-N","_score":17.083544},{"query":"3746","_id":"OEXHQOGQTVQTAT-UHFFFAOYSA-N","_score":17.083544},{"query":"2764","_id":"MYSWGUAQZAJSOK-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00537"}},{"query":"2187","_id":"YBBLVLTVTVSKRW-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB01217"}},{"query":"2182","notfound":true},{"query":"13342","_id":"JXLYSJRDGCGARV-CFWMRBGOSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00570"}},{"query":"4473","_id":"ZBBHBTPTTSWHBA-UHFFFAOYSA-O","_score": ...
# 200 [{"query":"4499","_id":"VKQFCGNPDRICFG-UHFFFAOYSA-N","_score":17.083454,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00401"}},{"query":"4812","_id":"MBWXNTAXLNYFJB-UHFFFAOYSA-N","_score":17.083544},{"query":"2269","_id":"MQTOSJVFKKJCRP-UHFFFAOYSA-N","_score":17.08357},{"query":"2266","_id":"BDJRBEYXGGNYIS-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00548"}},{"query":"2267","_id":"MBUVEWMHONZEQD-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00972"}},{"query":"2265","_id":"LMEKQMALGUDUQG-UHFFFAOYSA-N","_score":17.083454,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00993"}},{"query":"4819","_id":"QCHFTSOMWOSFHM-UHFFFAOYSA-N","_score":17.083544},{"query":"414","_id":"XOKCJXZZNAUIQN-UHFFFAOYSA-N","_score":17.083544},{"query":"4635","_id":"BRUQQQPBMZOVGD-UHFFFAOYSA-N","_score":17.083454},{"query":"4634","_id":"XIQVNETUBQGFHX-UHFFFAOYSA-N","_score":17.083454,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB01062"}},{"query":"1046","_id":"IPEHBUMCGVEMRF-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00339"}},{"query":"60953","_id":"GAGWJHPBXLXJQN-UORFTKCHSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB01101"}},{"query":"581","_id":"PWKSKIMOESPYIA-UHFFFAOYSA-N","_score":17.08357},{"query":"60795","_id":"CEUORZQYGODEFX-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB01238"}},{"query":"2891","_id":"AGVAZMGAQJOSFJ-UHFFFAOYSA-M","_score":17.083454},{"query":"272","notfound":true},{"query":"2895","_id":"JURKNVYFZMSNLP-UHFFFAOYSA-N","_score":17.083454,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00924"}},{"query":"2726","_id":"ZPEIMTDSQAKGNT-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00477"}},{"query":"2725","_id":"SOYKEARSMXGVTM-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB01114"}},{"query":"145068","_id":"MWUXSHHQAYIFBG-UHFFFAOYSA-N","_score":17.083454,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00435"}},{"query":"3637","_id":"RPTUSVTUFVMDQK-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB01275"}},{"query":"3639","_id":"JZUFKLXOESDKRF-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00999"}},{"query":"3419","_id":"BIDNLKIUORFRQP-UHFFFAOYSA-M","_score":17.08357},{"query":"341","_id":"COVFEVWNJUOYRL-UHFFFAOYSA-N","_score":17.08357},{"query":"3414","_id":"ZJAOAACCNHFJAH-UHFFFAOYSA-K","_score":17.083544},{"query":"2092","_id":"WNMJYKCGWZFFKR-UHFFFAOYSA-N","_score":17.083454,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00346"}},{"query":"2099","_id":"JSWZEAMFRNKZNL-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00969"}},{"query":"3062","_id":"LTMHDMANZUZIPE-UHFFFAOYSA-N","_score":17.083544},{"query":"5771","_id":"XNOPRXBHLZRZKH-UHFFFAOYSA-N","_score":17.083454},{"query":"5155","_id":"XNKLLVCARDGLGL-UHFFFAOYSA-N","_score":17.08357},{"query":"5152","_id":"GIIZNNXWQWCKIB-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00938"}},{"query":"4829","_id":"HYAFETHFCAUJAY-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB01132"}},{"query":"2274","_id":"WZPBZJONDBGPKJ-UHFFFAOYSA-N","_score":17.083544},{"query":"5556","_id":"JOFWLTCLBGQGBO-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00897"}},{"query":"4609","_id":"DRMCATBEKSVAPL-UHFFFAOYSA-N","_score":17.083544},{"query":"4603","_id":"VSZGPKBBMSAYNT-UHFFFAOYSA-N","_score":17.08357},{"query":"4601","_id":"QVYRGXJJSLMXQH-UHFFFAOYSA-N","_score":17.083454,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB01173"}},{"query":"4607","_id":"UWYHMGVUTGAWSP-UHFFFAOYSA-M","_score":17.083544},{"query":"1071","_id":"FPIPGXGPPP ...
# 200 [{"query":"5584","_id":"ZSCDBOWYZJWBIY-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00726"}},{"query":"3883","_id":"MJIHNNLFOKEZEW-UHFFFAOYSA-N","_score":17.083454,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00448"}},{"query":"4675","_id":"GVEAYVLWDAFXET-UHFFFAOYSA-N","_score":17.083544},{"query":"4674","_id":"WRUUGTRCQOWXEG-UHFFFAOYSA-N","_score":17.083454,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00282"}},{"query":"4679","_id":"IQPSEEYGBUAQFF-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00213"}},{"query":"48175","_id":"BDSYKGHYMJNPAB-YKQIDFLYSA-N","_score":17.083544},{"query":"41317","_id":"IHUNBGSDBOWDMA-UHFFFAOYSA-N","_score":17.083544},{"query":"4189","_id":"BYBLEWFAAKGYCD-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB01110"}},{"query":"71329","_id":"IXTMWRCNAAVVAI-UHFFFAOYSA-N","_score":17.083454,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00204"}},{"query":"3676","_id":"NNJVILVZKWQKPM-UHFFFAOYSA-N","_score":17.083454,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00281"}},{"query":"3675","_id":"RMUCZJUITONUFY-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00780"}},{"query":"3672","_id":"HEFNNWSXXWATRW-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB01050"}},{"query":"3476","_id":"WIGIZIANZCJQQY-UHFFFAOYSA-N","_score":17.08357},{"query":"3478","_id":"ZJJXGWJIGJFDTL-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB01067"}},{"query":"2585","_id":"OGHNVEJMJSYVRP-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB01136"}},{"query":"34312","_id":"CTRLABGOLIVAIY-UHFFFAOYSA-N","_score":17.083454,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00776"}},{"query":"5731","_id":"ULSDMUVEXKOYBU-UHFFFAOYSA-N","_score":17.08357},{"query":"5732","_id":"ZAFYATHCZYHLPB-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00425"}},{"query":"5735","_id":"GBBSUAFBMRNDJC-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB01198"}},{"query":"5734","_id":"UBQNRHZMVUUOMG-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00909"}},{"query":"3324","_id":"GGXKWVWZWMLJEH-UHFFFAOYSA-N","_score":17.083454,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00426"}},{"query":"3325","_id":"XUFQPHANEAPEMJ-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00927"}},{"query":"3454","notfound":true},{"query":"643511","_id":"HOBJEFOCIRXQKH-BYPYZUCNSA-N","_score":17.083544},{"query":"4463","_id":"NQDJXKOVJZTUJA-UHFFFAOYSA-N","_score":17.083454,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00238"}},{"query":"5596","_id":"OYYDSUSKLWTMMQ-UHFFFAOYSA-N","_score":17.08357},{"query":"444013","_id":"HBEAOBRDTOXWRZ-UHFFFAOYSA-K","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00538"}},{"query":"4645","notfound":true},{"query":"169","_id":"VNYSSYRCGWBHLG-UHFFFAOYSA-N","_score":17.08357},{"query":"5473385","_id":"UHLHHUAQNRJGFS-UHFFFAOYSA-N","_score":17.083544},{"query":"3198","_id":"LEZWWPYKPKIXLL-UHFFFAOYSA-N","_score":17.083454,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB01127"}},{"query":"3661","_id":"RKUNBYITZUJHSG-UHFFFAOYSA-N","_score":17.08357},{"query":"15061","_id":"VFZYDBOHAXCBKP-UHFFFAOYSA-N","_score":17.083454},{"query":"3449","_id":"ASUTZQLVASHGKV-UHFFFAOYSA-N","_score":17.083544},{"query":"213","_id":"DSNBHJFQCNUKMA-UHFFFAOYSA-N","_score":17.083454},{"query":"3339","_id":"YMTINGFKWWXKFG-UHFFFAOYSA-N","_score":17.083454,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB01039"}},{"query":"344","_id":"SHFQRUVRUBHHRE-UHFFFAOYSA-N","_score":17.083544},{"query":"3333","_id":"RZTAMFZIAATZDJ-UHFFFAOYSA-N","_score":17.08 ...
# 200 [{"query":"5311048","_id":"ZSWDZQGVDJWLBK-UHFFFAOYSA-N","_score":17.083544},{"query":"3958","_id":"DIWRORZWFLOCLC-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00186"}},{"query":"3957","_id":"JCCNYMKQOSZNPW-UHFFFAOYSA-N","_score":17.083454,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00455"}},{"query":"3954","_id":"RDOIQAHITMMDAJ-UHFFFAOYSA-O","_score":17.083544},{"query":"14888","_id":"QTLQKAJBUDWPIB-UHFFFAOYSA-N","_score":17.083454},{"query":"2978","_id":"CYQFCXCEBYINGO-UHFFFAOYSA-N","_score":17.08357},{"query":"2973","_id":"UBQYURCVBFRUQT-UHFFFAOYSA-N","_score":17.083454,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00746"}},{"query":"2812","_id":"VNFPBHJOKIVQEB-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00257"}},{"query":"2818","notfound":true},{"query":"216239","_id":"MLDQJTXFUGDVEO-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00398"}},{"query":"3143","_id":"ZDZOTLJHXYCWBA-UHFFFAOYSA-N","_score":17.083544},{"query":"3148","_id":"UKTAZPQNNNJVKR-UHFFFAOYSA-N","_score":17.083454},{"query":"3767","_id":"QRXWMOHMRWLFEY-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00951"}},{"query":"3763","_id":"PIWKPBJCKXDKJR-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00753"}},{"query":"2142","_id":"LKCWBDHBTVXHDL-UHFFFAOYSA-N","_score":17.083454},{"query":"2141","_id":"JKOQGQFVAUAYPM-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB01143"}},{"query":"3365","_id":"RFHAOTPXVQNOHP-UHFFFAOYSA-N","_score":17.083454,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00196"}},{"query":"3494","_id":"ANGKOCUUWGHLCE-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00986"}},{"query":"3367","_id":"HBUBKKRHXORPQB-UHFFFAOYSA-N","_score":17.08357},{"query":"5402","_id":"DOMXUEMWDBAQBQ-UHFFFAOYSA-N","_score":17.083454},{"query":"5401","_id":"VCKUSRYTPJJLNI-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB01162"}},{"query":"2369","_id":"NWIUTZDMDHAVTP-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00195"}},{"query":"5408","_id":"MUMGGOZAMZWBJJ-UHFFFAOYSA-N","_score":17.083544},{"query":"4425","_id":"UZHSEJADLWPNLE-UHFFFAOYSA-N","_score":17.083544},{"query":"4932","_id":"JWHAUXFOSRPERK-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB01182"}},{"query":"4428","_id":"DQCKKXVULJGBQN-UHFFFAOYSA-N","_score":17.083454},{"query":"4205","_id":"RONZAEMNMFQXRA-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00370"}},{"query":"42","_id":"RFENOVFRMPRRJI-UHFFFAOYSA-N","_score":17.083544},{"query":"4201","_id":"ZIMGGGWCDYVHOY-UHFFFAOYSA-N","_score":17.083544},{"query":"60854","_id":"MVWVFYHBGMAFLY-UHFFFAOYSA-N","_score":17.083454,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00246"}},{"query":"3962","_id":"PCZOHLXUXFIOCF-UHFFFAOYSA-N","_score":17.083544},{"query":"3961","_id":"PSIFNNKUMBGKDQ-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00678"}},{"query":"3964","_id":"XJGVXQDUIWGIRW-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00408"}},{"query":"54547","_id":"WYUSVOMTXWRGEK-UHFFFAOYSA-N","_score":17.08357},{"query":"5311181","_id":"HIFJCPQKFCZDDL-ACWOEMLNSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB01088"}},{"query":"36339","_id":"NPUKDXXFDDZOKR-UHFFFAOYSA-N","_score":17.083454},{"query":"3157","_id":"RUZYUOTYCVRMRZ-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00590"}},{"query":"3154","_id":"IAVUPMFITXYVAF-UHFFFAOYSA-N","_score":17.08357},{"query":"122316","_id":"RUOKEQAAGRXIBM-UHFFFAOYSA-N","_score":17.08357},{"query":"3 ...
# 200 [{"query":"3902","_id":"HPJKCIUCZWXJDR-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB01006"}},{"query":"60184","_id":"IPVQLZZIHOAWMC-YXMSTPNBSA-N","_score":17.083544},{"query":"853","_id":"XUIIKFGFIJCVMT-UHFFFAOYSA-N","_score":17.083454},{"query":"9433","_id":"FQPFAHBPWDRTLU-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB01223"}},{"query":"453","_id":"FBPFZTCFMRRESA-UHFFFAOYSA-N","_score":17.083454},{"query":"45","_id":"ROBFUDYVXSDBQM-UHFFFAOYSA-N","_score":17.08357},{"query":"1983","_id":"RZVAJINKPMORJF-UHFFFAOYSA-N","_score":17.083454,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00316"}},{"query":"1986","_id":"BZKPWHYZMXOIDC-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00819"}},{"query":"153941","notfound":true},{"query":"375","_id":"TXKJNHBRVLCYFX-UHFFFAOYSA-N","_score":17.083544},{"query":"1262","notfound":true},{"query":"335","_id":"QWVGKYWNOKOFNN-UHFFFAOYSA-N","_score":17.083544},{"query":"3355","_id":"DJBNUMBKLMJRSA-UHFFFAOYSA-O","_score":17.08357},{"query":"4583","_id":"GSDSWSVVBLHKDQ-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB01165"}},{"query":"4585","notfound":true},{"query":"4909","_id":"DQMZLTXERSFNPB-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00794"}},{"query":"49","_id":"QHKABHOOEWYVLI-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB04074"}},{"query":"5184","_id":"STECJAGHUSJQJN-UHFFFAOYSA-N","_score":17.08357},{"query":"2405","_id":"VHYCDWMUTMEGQY-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00612"}},{"query":"9052","notfound":true},{"query":"4011","_id":"QSLMDECMDJKHMQ-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00934"}},{"query":"3911","_id":"GFIJNRVAKGFPGQ-UHFFFAOYSA-N","_score":17.08357},{"query":"3914","_id":"IXHBTMCLRNMKHZ-UHFFFAOYSA-N","_score":17.08357},{"query":"861","_id":"AUYYCJSJGJYCDS-UHFFFAOYSA-N","_score":17.083544},{"query":"59708","_id":"HPHUVLMMVZITSG-UHFFFAOYSA-N","_score":17.083454,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB11868"}},{"query":"71273","_id":"ZKMNUMMKYBVTFN-UHFFFAOYSA-N","_score":17.083454},{"query":"3108","_id":"IZEKFCXSFNUWAM-UHFFFAOYSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00975"}},{"query":"3724","_id":"NBQNWMBBSKPBAY-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB01249"}},{"query":"83786","notfound":true},{"query":"65027","notfound":true},{"query":"60815","_id":"ZTVQQQVZCWLTDF-UHFFFAOYSA-N","_score":17.083544,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00899"}},{"query":"54374","_id":"DEQANNDTNATYII-OLNBODJMSA-N","_score":17.08357},{"query":"5195","_id":"MEZLKOACVSPNER-UHFFFAOYSA-N","_score":17.083454},{"query":"5379","_id":"XUBOMFCQGDBHNK-UHFFFAOYSA-N","_score":17.083454,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB01044"}},{"query":"5372","_id":"QJJXYPPXXYFBGM-UHFFFAOYSA-N","_score":17.083544},{"query":"5376","_id":"NKANXQFJJICGDU-UHFFFAOYSA-N","_score":17.083454},{"query":"3929","_id":"TYZROVQLWOKYKF-UHFFFAOYSA-N","_score":17.083454},{"query":"32797","_id":"FCSHDIVRCWTZOX-RFGBNKILSA-N","_score":17.08357},{"query":"5282226","_id":"MKPLKVHSHYCHOC-AHTXBMBWSA-N","_score":17.08357,"drugbank":{"_license":"https://bit.ly/3Hikpvm","id":"DB00287"}}]

# %%
data.head()
# Out:
#      pubchem_id   ulms_id                side_effect_name drugbank_id
# 0  CID003062316  C1096328     central nervous system mass     DB01254
# 1  CID003062316  C0162830       Photosensitivity reaction     DB01254
# 2  CID003062316  C1611725    leukaemic infiltration brain     DB01254
# 3  CID003062316  C0541767  platelet adhesiveness abnormal     DB01254
# 4  CID003062316  C0242973         Ventricular dysfunction     DB01254

# %%
data.to_csv(output_file, index=False)

# %% [markdown]
# ### Format the data to match the biomedgps format
#
# More details on the data format can be found [here](https://open-prophetdb.github.io/biomedgps-data/graph_data_index/#knowledge-graph-file).
#
# Examples:
#
# | relation_type                  | resource | source_id | source_type | target_id   | target_type | source_name                    | target_name |
# |--------------------------------|----------|-----------|-------------|-------------|-------------|--------------------------------|-------------|
# | DGIDB::INHIBITOR::Gene:Compound| DGIDB    | ENTREZ:4311 | Gene        | MESH:D015244| Compound    | membrane metalloendopeptidase  | Thiorphan   |
# | DGIDB::INHIBITOR::Gene:Compound| DGIDB    | ENTREZ:4311 | Gene        | MESH:C097292| Compound    | membrane metalloendopeptidase  | aladotrilat |

# %%
import pandas as pd

input_file = "./ChSe-Decagon_monopharmacy_drugbank.csv"
output_file = "./formatted_biosnap_compound_sideeffect.csv"
formatted_data = pd.read_csv(input_file, sep=",")

# Currently, we don't have enough information to determine the target type. Disease or Symptom? BioMedGPS::SideEffect::Compound:Symptom or BioMedGPS::SideEffect::Compound:Disease
formatted_data["relation_type"] = ""
formatted_data["source_id"] = "DrugBank:" + formatted_data["drugbank_id"]
formatted_data["source_type"] = "Compound"
formatted_data["source_name"] = ""
formatted_data["target_id"] = "UMLS:" + formatted_data["ulms_id"]
formatted_data["target_type"] = ""
formatted_data["target_name"] = formatted_data["side_effect_name"]
formatted_data["resource"] = "BioSNAP"

formatted_data = formatted_data[
    [
        "source_id",
        "source_type",
        "source_name",
        "target_id",
        "target_type",
        "target_name",
        "relation_type",
        "resource",
    ]
]

formatted_data.to_csv(output_file, index=False, sep="\t")

# %% [markdown]
# #### Determine the target_type for the side effects, map the side effect ids to the disease ids

# %%
disease_

relation_type = "BioMedGPS::SideEffect::Compound:Disease"
target_type = "Disease"

# %% [markdown]
# #### Determine the target_type for the side effects, map the side effect ids to the symptom ids

# %%
relation_type = "BioMedGPS::SideEffect::Compound:Symptom"
target_type = "Symptom"
