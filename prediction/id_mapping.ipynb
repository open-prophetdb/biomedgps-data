# %%
import os
import pandas as pd
import sys

rootdir = os.path.abspath(os.path.join(".."))
sys.path.append(os.path.join(rootdir, "lib"))

from utils import get_matched_id, get_matched_name
from graph import load_entities

# %%
datadir = os.path.join(rootdir, "graph_data")
entities = load_entities(datadir)

# %%
data = pd.read_csv("./examples/mecfs.tsv", sep="\t")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/jy006/Documents/Code/BioMedGPS/biomedgps-data/models/id_mapping.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/Users/jy006/Documents/Code/BioMedGPS/biomedgps-data/models/id_mapping.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> data = pd.read_csv("./examples/mecfs.tsv", sep="\t")
#
# File ~/miniconda3/envs/biomedgps/lib/python3.11/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/envs/biomedgps/lib/python3.11/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~/miniconda3/envs/biomedgps/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~/miniconda3/envs/biomedgps/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~/miniconda3/envs/biomedgps/lib/python3.11/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './examples/mecfs.tsv'

# %%
source_ids = data["source_id"].to_list()
source_types = data["source_type"].to_list()
data['matched_source_id'] = [get_matched_id(id, etype, entities) for id, etype in zip(source_ids, source_types)]
data['matched_source_name'] = [get_matched_name(id, etype, entities) for id, etype in zip(source_ids, source_types)]

target_ids = data["target_id"].to_list()
target_types = data["target_type"].to_list()
data['matched_target_id'] = [get_matched_id(id, etype, entities) for id, etype in zip(target_ids, target_types)]
data['matched_target_name'] = [get_matched_name(id, etype, entities) for id, etype in zip(target_ids, target_types)]

# %%
data.to_csv('./examples/mecfs_matched.tsv', sep='\t', index=False)

# %%
entities[entities["id"].str.contains("WikiPathways")]
# Out:
#                         id                                               name  \
# 809779  WikiPathways:WP100                             Glutathione metabolism
# 809780  WikiPathways:WP106                   Alanine and aspartate metabolism
# 809781  WikiPathways:WP107                                Translation Factors
# 809782  WikiPathways:WP111                           Electron Transport Chain
# 809783  WikiPathways:WP117                                       GPCRs, Other
# ...                    ...                                                ...
# 812725    WikiPathways:WP8                             IL-9 signaling pathway
# 812726   WikiPathways:WP81          Complement activation - classical pathway
# 812727   WikiPathways:WP86                                  Heme biosynthesis
# 812728   WikiPathways:WP89  FAS pathway and stress induction of HSP regula...
# 812729   WikiPathways:WP94        Hepatocyte growth factor receptor signaling
#
#           label      resource  \
# 809779  Pathway      Hetionet
# 809780  Pathway      Hetionet
# 809781  Pathway      Hetionet
# 809782  Pathway      Hetionet
# 809783  Pathway      Hetionet
# ...         ...           ...
# 812725  Pathway  WikiPathways
# 812726  Pathway  WikiPathways
# 812727  Pathway  WikiPathways
# 812728  Pathway  WikiPathways
# 812729  Pathway  WikiPathways
#
#                                               description synonyms pmids  \
# 809779                                                NaN      NaN   NaN
# 809780                                                NaN      NaN   NaN
# 809781                                                NaN      NaN   NaN
# 809782                                                NaN      NaN   NaN
# 809783                                                NaN      NaN   NaN
# ...                                                   ...      ...   ...
# 812725                                                NaN      NaN   NaN
# 812726                                                NaN      NaN   NaN
# 812727  The enzymatic process that produces heme is pr...      NaN   NaN
# 812728  This pathway describes the Fas induced apoptos...      NaN   NaN
# 812729  Signaling pathway of the Hepatocyte Growth Fac...      NaN   NaN
#
#         taxid xrefs
# 809779    NaN   NaN
# 809780    NaN   NaN
# 809781    NaN   NaN
# 809782    NaN   NaN
# 809783    NaN   NaN
# ...       ...   ...
# 812725  10116   NaN
# 812726  10116   NaN
# 812727  10116   NaN
# 812728  10116   NaN
# 812729  10116   NaN
#
# [1894 rows x 9 columns]
